# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'

# %%
df = pd.read_csv(data)

# %%
df.head() # step 1
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.info() # step 2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       201 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %%
df.describe(include='all')
# Out:
#          symboling  normalized-losses    make aspiration num-of-doors  \
# count   201.000000          201.00000     201        201          201
# unique         NaN                NaN      22          2            2
# top            NaN                NaN  toyota        std         four
# freq           NaN                NaN      32        165          115
# mean      0.840796          122.00000     NaN        NaN          NaN
# std       1.254802           31.99625     NaN        NaN          NaN
# min      -2.000000           65.00000     NaN        NaN          NaN
# 25%       0.000000          101.00000     NaN        NaN          NaN
# 50%       1.000000          122.00000     NaN        NaN          NaN
# 75%       2.000000          137.00000     NaN        NaN          NaN
# max       3.000000          256.00000     NaN        NaN          NaN
#
#        body-style drive-wheels engine-location  wheel-base      length  ...  \
# ...

# %%
# dependent variable/ response/ output/ label/ y
y = df['price']

# %%
# independent variable/ feature/input/x
x = df[['horsepower']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
trainx, testx, trainy, testy = train_test_split(x,y,test_size=.2, random_state=0)

# %%
plt.scatter(trainx,trainy,c='red',alpha=.3)
plt.show()

# %%
model = LinearRegression()
model.fit(trainx,trainy)
score = model.score(testx,testy) * 100
print(f'the model acheived a score = {score}')
# Out:
# the model acheived a score = 78.27421900758173

# %%
ypred = model.predict(trainx)

# %%
plt.scatter(trainx,trainy,c='red',alpha=.3,label='original')
plt.plot(trainx,ypred,'g-.',label='prediction')
plt.title("prediction")
plt.xlabel('horsepower')
plt.ylabel('price')
plt.text(50,45000,f'R2 = {score}')
plt.legend()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       201 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %% [markdown]
# ## task 1
# write many programs to create the linear regression model between remaining numeric cols and price(y) and display the graphical output

# %% [markdown]
# ### WHAT IS THE VALUE OF INCERCEPT(a)
# ### WHAT IS THE VALUE OF SLOPE (b)

# %%
model.intercept_
# Out:
# -4118.879446320821

# %%
model.coef_
# Out:
# array([165.57449341])

# %% [markdown]
# `yhat = a + bX`
#
# now we have all data then we can predict y aka price of car

# %%
import pickle

def save_model(path, model):
    with open(path,'wb') as f:
        pickle.dump(model, f)
    return path

# %%
save_model('../../models/slr_hpvsprice_predictor.pkl',model)
# Out:
# '../../models/slr_hpvsprice_predictor.pkl'
